# %%
import pandas as pd

# %%
from google.colab import files
d = files.upload()
# Out:
#      <input type="file" id="files-f0359c99-7a32-4254-b8fb-255104534ecd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0359c99-7a32-4254-b8fb-255104534ecd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# JSON file
df = pd.read_json("sample.json", typ="series").to_frame().T
print(df)
# Out:
#                                                   0  \
# 0  {'name': 'Alice', 'age': 25, 'city': 'New York'}
#
#                                                    1  \
# 0  {'name': 'Bob', 'age': 30, 'city': 'Los Angeles'}
#
#                                                    2
# 0  {'name': 'Charlie', 'age': 35, 'city': 'Chicago'}

# %%
from google.colab import files
d = files.upload()
# Out:
#      <input type="file" id="files-190a20b0-e5ca-4720-8b55-0726b14b5172" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-190a20b0-e5ca-4720-8b55-0726b14b5172">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Excel file
df_excel = pd.read_excel('file.xls', sheet_name='Sheet1')
df_excel
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
from google.colab import files
d = files.upload()
# Out:
#      <input type="file" id="files-af594684-d89f-40d4-b1c9-243906b86659" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af594684-d89f-40d4-b1c9-243906b86659">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# XML file
df_xml = pd.read_xml('file.xml')
df_xml
# Out:
#          name   age                   email                 title  \
# 0    John Doe  30.0    john.doe@example.com                  None
# 1  Jane Smith  25.0  jane.smith@example.com                  None
# 2        None   NaN                    None  The Adventure Begins
#
#            author    year
# 0            None     NaN
# 1            None     NaN
# 2  Robert Johnson  2022.0

# %%
from google.colab import files
d = files.upload()
# Out:
#      <input type="file" id="files-b360b527-f6c5-453a-ac7a-920c27df7ee2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b360b527-f6c5-453a-ac7a-920c27df7ee2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# HTML file
# From local file
df_html = pd.read_html("sample.html", match="Name")  # Match column name
df = df_html[0]  # Extract the first found table
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
from google.colab import files
d = files.upload()

# %%
from google.colab import files
d = files.upload()
# Out:
#      <input type="file" id="files-fb2c27d9-7e61-46ac-ad85-a81121e3fd54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb2c27d9-7e61-46ac-ad85-a81121e3fd54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.concat(pd.read_excel("file_multi.xls", sheet_name=None))
df
# Out:
#             0 First Name  Last Name  Gender        Country  Age  \
# Sheet1 0    1      Dulce      Abril  Female  United States   32
#        1    2       Mara  Hashimoto  Female  Great Britain   25
#        2    3     Philip       Gent    Male         France   36
#        3    4   Kathleen     Hanner  Female  United States   25
#        4    5    Nereida    Magwood  Female  United States   58
# ...        ..        ...        ...     ...            ...  ...
# Sheet2 38  39    Shanice  Mccrystal  Female  United States   36
#        39  40      Chase     Karner    Male  United States   37
#        40  41     Tommie  Underdahl    Male  United States   26
#        41  42     Dorcas     Darity  Female  United States   37
#        42  43      Angel      Sanor    Male         France   24
#
#                           Date    Id
# Sheet1 0            15/10/2017  1562
#        1            16/08/2016  1582
#        2            21/05/2015  2587
#        3            15/10/2017  3549
# ...

# %%
# For specific Excel sheets/options
df_excel = pd.read_excel('file.xls',
    sheet_name='Sheet1',
    skiprows=2,           # Skip first 2 rows
    usecols='A:C',       # Use columns A to C
    na_values=['NA', '']) # Handle missing values

# %%
df_excel
# Out:
#      2       Mara   Hashimoto
# 0    3     Philip        Gent
# 1    4   Kathleen      Hanner
# 2    5    Nereida     Magwood
# 3    6     Gaston       Brumm
# 4    7       Etta        Hurn
# 5    8    Earlean      Melgar
# 6    9   Vincenza     Weiland
# 7   10     Fallon     Winward
# 8   11    Arcelia      Bouska
# 9   12   Franklyn      Unknow
# 10  13    Sherron    Ascencio
# 11  14     Marcel   Zabriskie
# 12  15       Kina    Hazelton
# 13  16   Shavonne         Pia
# 14  17     Shavon      Benito
# 15  18   Lauralee     Perrine
# 16  19     Loreta      Curren
# 17  20     Teresa      Strawn
# 18  21    Belinda     Partain
# 19  22      Holly        Eudy
# 20  23       Many      Cuccia
# 21  24     Libbie       Dalby
# 22  25     Lester     Prothro
# 23  26     Marvel        Hail
# 24  27    Angelyn        Vong
# 25  28  Francesca   Beaudreau
# 26  29      Garth       Gangi
# 27  30      Carla    Trumbull
# 28  31       Veta       Muntz
# 29  32     Stasia      Becker
# ...
