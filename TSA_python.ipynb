# %%
import datetime as dt

# %%
print(dt.date(2025,1,31))
# Out:
# 2025-01-31

# %%
dt.datetime(1987,8,4,18,45,48)
# Out:
# datetime.datetime(1987, 8, 4, 18, 45, 48)

# %%
dt.datetime.now()
# Out:
# datetime.datetime(2025, 3, 7, 17, 46, 32, 911355)

# %%
s = "2025-03-07  20:45:47"

# %%
s_dt = dt.datetime.strptime(s, "%Y-%m-%d %H:%M:%S")

# %%
s_dt.isoformat()
# Out:
# '2025-03-07T20:45:47'

# %%
s_dt.isocalendar()
# Out:
# datetime.IsoCalendarDate(year=2025, week=10, weekday=5)

# %%
s_dt.isoweekday()
# Out:
# 5

# %%
u = 90

# %%
s_dt.date()
# Out:
# datetime.date(2025, 3, 7)

# %%
s_dt.astimezone()
# Out:
# datetime.datetime(2025, 3, 7, 20, 45, 47, tzinfo=datetime.timezone(datetime.timedelta(0), 'UTC'))

# %%
s_dt.hour
# Out:
# 20

# %%
s_dt.day
# Out:
# 7

# %%
import numpy as np

# %%
dates = ['2023-01-05','2023-01-07','2023-01-10','2023-01-12','2023-01-15' ]

# %%
d_np = np.array(dates, dtype= 'datetime64')

# %%
d_np
# Out:
# array(['2023-01-05', '2023-01-07', '2023-01-10', '2023-01-12',
#        '2023-01-15'], dtype='datetime64[D]')

# %%
import pandas as pd

# %%
df = pd.DataFrame({'day1': ['2024 -10-01 07:37:15','2024 -10-03 07:30:15'],'value':[70,80]})

# %%
df
# Out:
#                    day1  value
# 0  2024 -10-01 07:37:15     70
# 1  2024 -10-03 07:30:15     80

# %%
df.set_index
# Out:
# <bound method DataFrame.set_index of                    day1  value
# 0  2024 -10-01 07:37:15     70
# 1  2024 -10-03 07:30:15     80>

# %%
df_d = pd.to_datetime(dates)

# %%
df_d
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-07', '2023-01-10', '2023-01-12',
#                '2023-01-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
type(df_d)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
d = {'A':['2023-01-05','2023-01-07','2023-01-10','2023-01-12','2023-01-15' ],'score':[9,7,6,5,6]}

# %%
type(d)
# Out:
# dict

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#             A  score
# 0  2023-01-05      9
# 1  2023-01-07      7
# 2  2023-01-10      6
# 3  2023-01-12      5
# 4  2023-01-15      6

# %%
df['A'] = pd.to_datetime(df['A'])

# %%
df
# Out:
#            A  score
# 0 2023-01-05      9
# 1 2023-01-07      7
# 2 2023-01-10      6
# 3 2023-01-12      5
# 4 2023-01-15      6

# %%
df.set_index('A')
# Out:
#             score
# A
# 2023-01-05      9
# 2023-01-07      7
# 2023-01-10      6
# 2023-01-12      5
# 2023-01-15      6

# %%
df
# Out:
#            A  score
# 0 2023-01-05      9
# 1 2023-01-07      7
# 2 2023-01-10      6
# 3 2023-01-12      5
# 4 2023-01-15      6

# %%
#axis axes
