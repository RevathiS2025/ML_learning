# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = [6,8,4,9,2,5,8,9,1,6]

# %%
x=range(1,11)

# %%
plt.plot(x,s)

# %%
subject = ['Tamil','English','Maths','Science','SocialScience']

# %%
Marks = [66,77,88,99,45]

# %%
plt.bar(subject,Marks, color = 'green') # plt.show
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(subject,Marks, color = 'green')
# Out:
# <BarContainer object of 5 artists>

# %%
bars = plt.bar([1, 2, 3, 4], [1.3, 2.5, 3.7, 4.9])
bars[0].set_color('#0f0d0e40')
bars[1].set_color('aquamarine')
bars[2].set_color('red')

# %%
sasi = (69,50,45,90,49)
senthil = (78,90,67,90,58)
index = np.array([1,2,3,4,5])
width = 0.30
plt.bar(index,sasi,width,label = 'a')
plt.bar(index+width,senthil, width , label ="b")
# Out:
# <BarContainer object of 5 artists>

# %%
kathir = np.array([70,80,97,70,67])
plt.bar(index,sasi, width = 0.5, label = 'sasi_marks', color = 'red',bottom = senthil+kathir)
plt.bar(index, senthil, width = 0.5, label = ' senthil_marks',color = 'green',bottom = kathir)
plt.bar(index, kathir, width = 0.5, label = ' senthil_marks',color = 'blue')
# Out:
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
ax = plt.subplots()
#ax.pie(sizes, labels=labels)

# %%
from google.colab import files
d = files.upload()
# Out:
#      <input type="file" id="files-cb37a89b-1b32-4fc6-b3a0-1c311521ccbd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb37a89b-1b32-4fc6-b3a0-1c311521ccbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Salary_Data[1] (1).csv')

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Years of Experience'}>],
#        [<Axes: title={'center': 'Salary'}>, <Axes: >]], dtype=object)

# %%
s1 = np.random.normal(0,10,1000)
s2 = np.random.normal(4,10,1000)
s3 = np.random.normal(6,10,1000)
s4 = np.random.normal(-8,10,1000)
s5 = np.random.normal(-2,10,1000)

# %%
colors = ['red','green','blue','orange','yellow']

# %%
plt.hist([s1,s2,s3,s4,s5],bins = 7, stacked=True, color = colors, alpha = 0.3)
# Out:
# (array([[  18.,  142.,  371.,  356.,  108.,    5.,    0.],
#         [  21.,  208.,  672.,  794.,  273.,   32.,    0.],
#         [  21.,  259.,  891., 1253.,  510.,   63.,    3.],
#         [  93.,  564., 1334., 1416.,  525.,   65.,    3.],
#         [ 115.,  733., 1744., 1734.,  597.,   74.,    3.]]),
#  array([-33.94347642, -22.38989196, -10.8363075 ,   0.71727696,
#          12.27086142,  23.82444587,  35.37803033,  46.93161479]),
#  <a list of 5 BarContainer objects>)

# %%
x = np.random.normal(5,10,1000)
y = np.random.normal(10,2,1000)
plt.scatter(x,y, color='red', edgecolors= 'yellow', marker='$\clubsuit$')

# %%
x1 = np.random.randint(0,100,500)
y1 = 100-x1 + np.random.randint(0,10,500)

# %%
np.corrcoef(x1,y1)
plt.scatter(x1,y1)
